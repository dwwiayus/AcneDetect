# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("dataset_skincare_ready.csv")
df.head()
# Out:
#             Brand                 Produk Jenis_Produk_Final  \
# 0         Avoskin      Tea Tree Spot Gel     Spot Treatment
# 1  Dear Me Beauty  Bakuchiol Night Cream        Night Cream
# 2       Somethinc       Glow Boost Serum              Serum
# 3           COSRX   Acne Treatment Serum              Serum
# 4    The Ordinary      Tea Tree Spot Gel     Spot Treatment
#
#   Tipe_Bahan_Aktif_Final Masalah Kulit Untuk Kulit ingredient_name  \
# 0               Tea Tree       Jerawat   Berminyak        tea tree
# 1              Bakuchiol     Dehidrasi      Kering       bakuchiol
# 2         Salicylic Acid    Flek hitam   Berminyak  Salicylic Acid
# 3              Bakuchiol       Iritasi   Berminyak       bakuchiol
# 4               Tea Tree         Kusam   Berminyak        tea tree
#
#            function1            function2  \
# 0          Acne care  Oil control support
# 1  Skin conditioning   Anti-aging support
# 2         Exfoliant             Tidak Ada
# ...
